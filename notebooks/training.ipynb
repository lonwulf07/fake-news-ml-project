# %%
import pandas as pd
import numpy as np

fake = pd.read_csv("data/Fake.csv")
true = pd.read_csv("data/True.csv")

fake["label"] = 0
true["label"] = 1

df = pd.concat([fake, true])

df = df[["text", "label"]]

df = df.sample(frac=1)

df.head()
# Out:
#                                                     text  label
# 11414  DUBAI (Reuters) - Iran s Supreme Court has uph...      1
# 21894  This is just one we caught crossing the border...      0
# 9404   You d think reporters would learn to ask quest...      0
# 5945   Vice President Joe Biden followed up Senator E...      0
# 13157  PARIS (Reuters) - French President Emmanuel Ma...      1

# %% [markdown]
# # **Text Processing**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english', max_df=0.7)

X = vectorizer.fit_transform(df['text'])

y = df['label']

# %% [markdown]
# # **Train Model**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2
)

# %% [markdown]
# # **Logistic Regression Model**

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # **Evaluate**

# %%
from sklearn.metrics import accuracy_score

pred = model.predict(X_test)

print(accuracy_score(y_test, pred))
# Out:
# 0.9826280623608018

# %% [markdown]
# # **Save Model**

# %%
import joblib

joblib.dump(model, "model.pkl")

joblib.dump(vectorizer, "vectorizer.pkl")
# Out:
# ['vectorizer.pkl']
